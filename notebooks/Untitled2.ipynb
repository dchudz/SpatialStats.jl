# %%
using SpatialStats; s = SpatialStats
reload("src/SpatialStats.jl")
include("test/SpatialStats_test.jl")
# Out:
# D3(120.0,80.0,IOBuffer([0x66,0x75,0x6e,0x63,0x74,0x69,0x6f,0x6e,0x20,0x64  …  0x20,0x3d,0x20,0x64,0x72,0x61,0x77,0x0a,0x7d,0x0a],true,true,true,false,30530,9223372036854775807,30531),0,[],[],1,3,[0x03e4a560241e7014=>({LCHab(65.0,70.0,100.43478260869566),LCHab(65.0,70.0,100.43478260869566),LCHab(65.0,70.0,100.43478260869566),LCHab(65.0,70.0,100.43478260869566),LCHab(65.0,70.0,100.43478260869566),LCHab(65.0,70.0,100.43478260869566),LCHab(65.0,70.0,100.43478260869566),LCHab(65.0,70.0,100.43478260869566),LCHab(65.0,70.0,100.43478260869566),LCHab(65.0,70.0,100.43478260869566)  …  LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0),LCHab(55.0,60.0,240.0)},3),0x04fbbd4aa64a8e8d=>([38.45502874878756,33.181565003031594,41.2196734595677,30.450738498738687,28.971239711020292,31.152404133556903,29.506994723311784,31.84065741361654,34.062311827
# ...

# %%
s.SquaredExponentialCov()
# Out:
# SquaredExponentialCov(1,1,0)
